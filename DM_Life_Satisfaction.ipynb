# %% [markdown]
# <a href="https://colab.research.google.com/github/21002572uhi/21002572_DataAnalytics/blob/main/DM_Life_Satisfaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls <- read.csv("https://raw.githubusercontent.com/21002572uhi/21002572_DataAnalytics/main/LifeSatisfactionWorldBankData.csv")

# %%
head(ls)
# Out:
#   LOCATION Country        Value GDPpercapita
# 1 AUS      Australia      7.1   51722.07
# 2 AUT      Austria        7.2   48809.23
# 3 BEL      Belgium        6.8   45517.90
# 4 CAN      Canada         7.0   43349.68
# 5 CZE      Czech Republic 6.9   22992.88
# 6 DNK      Denmark        7.5   60915.42

# %%
summary(ls)
# Out:
#    LOCATION           Country              Value      GDPpercapita
#  Length:41          Length:41          Min.   :4.9   Min.   :  5304
#  Class :character   Class :character   1st Qu.:6.1   1st Qu.: 17659
#  Mode  :character   Mode  :character   Median :6.5   Median : 31919
#                                        Mean   :6.6   Mean   : 36580
#                                        3rd Qu.:7.2   3rd Qu.: 49170
#                                        Max.   :7.9   Max.   :117370

# %%
plot(ls$Value, ls$GDPpercapita, main="Happiness Score vs GDP Per Capita, 2020")
abline(lm(ls$GDPpercapita ~ ls$Value))
# Out:
# Plot with title “Happiness Score vs GDP Per Capita, 2020”
